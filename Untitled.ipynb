# %%
import pandas as pd
import os

# %%
os.chdir('/Users/rishav/nasa-cmaps')
print(os.getcwd())
# Out:
# /Users/rishav/nasa-cmaps

# %%
print(os.listdir('CMaps'))
# Out:
# ['Damage Propagation Modeling.pdf', 'train_FD001.txt', 'train_FD003.txt', 'RUL_FD004.txt', 'train_FD002.txt', 'RUL_FD001.txt', 'x.txt', 'RUL_FD003.txt', 'RUL_FD002.txt', 'train_FD004.txt', 'test_FD003.txt', 'test_FD002.txt', 'test_FD001.txt', 'test_FD004.txt', 'readme.txt']

# %%
import pandas as pd

# Define column names based on CMAPSS standard
columns = ["unit_number", "time_in_cycles", "operational_setting_1", "operational_setting_2",
           "operational_setting_3"] + [f"sensor_measurement_{i}" for i in range(1, 22)]

# Load training data
train_df = pd.read_csv("CMaps/train_FD001.txt", sep=" ", header=None)
train_df.dropna(axis=1, how='all', inplace=True)  # drop empty columns
train_df.columns = columns

# Preview
train_df.head()
# Out:
#    unit_number  time_in_cycles  operational_setting_1  operational_setting_2  \
# 0            1               1                -0.0007                -0.0004
# 1            1               2                 0.0019                -0.0003
# 2            1               3                -0.0043                 0.0003
# 3            1               4                 0.0007                 0.0000
# 4            1               5                -0.0019                -0.0002
#
#    operational_setting_3  sensor_measurement_1  sensor_measurement_2  \
# 0                  100.0                518.67                641.82
# 1                  100.0                518.67                642.15
# 2                  100.0                518.67                642.35
# 3                  100.0                518.67                642.35
# 4                  100.0                518.67                642.37
#
#    sensor_measurement_3  sensor_measurement_4  sensor_measurement_5  ...  \
# ...

# %%
rul_df = pd.read_csv("CMaps/RUL_FD001.txt", header=None)
rul_df.columns = ["RUL"]
rul_df.head()
# Out:
#    RUL
# 0  112
# 1   98
# 2   69
# 3   82
# 4   91

# %%
test_df = pd.read_csv("CMaps/test_FD001.txt", sep=" ", header=None)
test_df.dropna(axis=1, how='all', inplace=True)
test_df.columns = columns
